# %%
import subprocess
import sys
subprocess.check_call([sys.executable,"-m","pip", "install", "yfinance"])
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tickerSymbol='BARC.L'
tickerData=yf.Ticker(tickerSymbol)

# %%
Daily = tickerData.history(period='1d', start='2023-01-01', end='2023-12-31')

Daily = Daily.reset_index()
print(Daily)

daily=Daily[["Date","Close"]]
print(daily)

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(daily['Date'], daily['Close'], marker='o', linestyle='-')
plt.title(f'{tickerSymbol} Close Price (2024-01-01 to 2024-12-31)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                          Date        Open        High         Low       Close  \
# 0   2023-01-03 00:00:00+00:00  145.395247  149.761108  144.994204  149.113983
# 1   2023-01-04 00:00:00+00:00  149.569711  153.388694  149.569711  153.197296
# 2   2023-01-05 00:00:00+00:00  152.376988  158.356142  151.629602  157.153015
# 3   2023-01-06 00:00:00+00:00  156.606137  157.408208  156.168629  156.861343
# 4   2023-01-09 00:00:00+00:00  156.861350  158.738945  156.660829  157.335297
# ..                        ...         ...         ...         ...         ...
# 246 2023-12-21 00:00:00+00:00  143.429907  145.838891  142.321022  144.749115
# 247 2023-12-22 00:00:00+00:00  143.296081  145.380048  143.276973  145.093262
# 248 2023-12-27 00:00:00+00:00  145.877128  147.903725  144.213779  146.890427
# 249 2023-12-28 00:00:00+00:00  146.699256  147.253691  146.068330  146.737488
# 250 2023-12-29 00:00:00+00:00  146.622770  147.043388  146.221275  147.005142
#
#        Volume  Dividends  Stock Splits
# 0    34940227        0.0           0.0
# 1    31851649        0.0           0.0
# 2    40113321        0.0           0.0
# 3    23266356        0.0           0.0
# 4    32930427        0.0           0.0
# ..        ...        ...           ...
# 246  55268216        0.0           0.0
# 247  13070297        0.0           0.0
# 248  26184336        0.0           0.0
# 249  21442794        0.0           0.0
# 250  10578303        0.0           0.0
#
# [251 rows x 8 columns]
#                          Date       Close
# 0   2023-01-03 00:00:00+00:00  149.113983
# 1   2023-01-04 00:00:00+00:00  153.197296
# 2   2023-01-05 00:00:00+00:00  157.153015
# 3   2023-01-06 00:00:00+00:00  156.861343
# 4   2023-01-09 00:00:00+00:00  157.335297
# ..                        ...         ...
# 246 2023-12-21 00:00:00+00:00  144.749115
# 247 2023-12-22 00:00:00+00:00  145.093262
# 248 2023-12-27 00:00:00+00:00  146.890427
# 249 2023-12-28 00:00:00+00:00  146.737488
# 250 2023-12-29 00:00:00+00:00  147.005142
#
# [251 rows x 2 columns]

# %%
# Get minute-by-minute data for the last 1 day
Intra = yf.download(tickerSymbol, period='1d', interval='1m')

Intra = Intra.reset_index()

print(Intra)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                      Datetime        Open        High         Low       Close  \
# 0   2024-09-24 08:00:00+01:00  223.750000  223.949997  223.390106  223.649994
# 1   2024-09-24 08:01:00+01:00  223.800003  223.837402  223.789993  223.809998
# 2   2024-09-24 08:02:00+01:00  223.800003  224.300003  223.449997  224.300003
# 3   2024-09-24 08:03:00+01:00  223.850006  224.550003  223.850006  224.500000
# 4   2024-09-24 08:04:00+01:00  224.500000  224.500000  224.300003  224.449997
# ..                        ...         ...         ...         ...         ...
# 314 2024-09-24 13:16:00+01:00  228.149994  228.149994  228.100006  228.100006
# 315 2024-09-24 13:17:00+01:00  228.050003  228.199997  228.050003  228.199997
# 316 2024-09-24 13:18:00+01:00  228.100006  228.100006  228.100006  228.100006
# 317 2024-09-24 13:19:00+01:00  228.244995  228.244995  228.149994  228.199997
# 318 2024-09-24 13:20:00+01:00  228.149994  228.149994  228.149994  228.149994
#
#       Adj Close  Volume
# 0    223.649994       0
# 1    223.809998   12281
# 2    224.300003   37328
# 3    224.500000  181392
# 4    224.449997   42620
# ..          ...     ...
# 314  228.100006    3722
# 315  228.199997    2724
# 316  228.100006    6002
# 317  228.199997   20061
# 318  228.149994       0
#
# [319 rows x 7 columns]

# %%
intra=Intra[["Datetime","Close"]]
print(intra)


# Plotting the data
plt.figure(figsize=(15, 8))
plt.plot(intra['Datetime'], intra['Close'], marker='o', linestyle='-', markersize=2, alpha=0.7)
plt.xlabel('Datetime')
plt.ylabel('Close Price')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                      Datetime       Close
# 0   2024-09-24 08:00:00+01:00  223.649994
# 1   2024-09-24 08:01:00+01:00  223.809998
# 2   2024-09-24 08:02:00+01:00  224.300003
# 3   2024-09-24 08:03:00+01:00  224.500000
# 4   2024-09-24 08:04:00+01:00  224.449997
# ..                        ...         ...
# 314 2024-09-24 13:16:00+01:00  228.100006
# 315 2024-09-24 13:17:00+01:00  228.199997
# 316 2024-09-24 13:18:00+01:00  228.100006
# 317 2024-09-24 13:19:00+01:00  228.199997
# 318 2024-09-24 13:20:00+01:00  228.149994
#
# [319 rows x 2 columns]

# %%
# Get weekly data for the last 3 months
Weekly = yf.download(tickerSymbol, period='3mo', interval='1wk')


Weekly = Weekly.reset_index()

weekly=Weekly[["Date","Close"]]
# Display the data
print(weekly)

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(weekly['Date'], weekly['Close'], marker='o', linestyle='-')
plt.title(f'{tickerSymbol} Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#          Date       Close
# 0  2024-06-24  208.899994
# 1  2024-07-01  220.550003
# 2  2024-07-08  222.449997
# 3  2024-07-15  228.649994
# 4  2024-07-22  231.399994
# 5  2024-07-29  209.100006
# 6  2024-08-05  218.250000
# 7  2024-08-12  228.300003
# 8  2024-08-19  230.449997
# 9  2024-08-26  228.399994
# 10 2024-09-02  220.850006
# 11 2024-09-09  221.149994
# 12 2024-09-16  226.750000
# 13 2024-09-23  228.149994
